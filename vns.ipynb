# %%
import pandas as pd

# %%
df = pd.read_csv('resultado_vns.csv')
df.head()
# Out:
#    Unnamed: 0                 datetime  step  k  neighbor  \
# 0           0  2025-10-11 06:05:51,807     0  0         0
# 1           1  2025-10-11 06:08:46,447     0  0         0
# 2           2  2025-10-11 06:09:18,659     1  1         0
# 3           3  2025-10-11 06:09:53,855     2  2         0
# 4           4  2025-10-11 06:10:08,250     2  2         1
#
#                       neighborhood  fitness_logistic_time  is_local_optimal  \
# 0    SimToSwapDQN.<locals>.wrapper                  61.55              True
# 1    SimToSwapDQN.<locals>.wrapper                  74.42              True
# 2                             Move                  63.44              True
# 3  SimToSwapCycle.<locals>.wrapper                  64.19             False
# 4  SimToSwapCycle.<locals>.wrapper                  63.44             False
#
#           start           end  simulation_time                     time  \
# 0  1.760174e+09  1.760174e+09          21.5609  2025-10-11 06:05:51.807
# ...

# %%
df['neighborhood'].value_counts()
# Out:
# neighborhood
# Move                               1614
# SimToSwapCycle.<locals>.wrapper     196
# SimToSwapDQN.<locals>.wrapper       190
# Name: count, dtype: int64
